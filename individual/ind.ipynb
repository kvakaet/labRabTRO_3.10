# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Выделение фрагмента фотографии

# %%
img = cv2.imread('willage.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

image = cv2.rectangle(img, (210, 230), (415, 270), (0, 0, 255), 2)
plt.axis('off')
plt.title('Табличка')
plt.imshow(image);

# %% [markdown]
# # Взятие контура
# Сначала возьмём сам фрагмент

# %%
crop = img[230:270, 210:415]
piece = cv2.resize(
    crop, 
    (200, 100), 
    interpolation=cv2.INTER_LINEAR
)

plt.axis('off')

plt.imshow(piece);

# %% [markdown]
# Теперь возьмём контур

# %%
img = cv2.cvtColor(piece, cv2.COLOR_RGB2GRAY)

ret, thresh = cv2.threshold(img, 75, 255, 0)
contours, hierarchy = cv2.findContours(thresh, 5, 5)
cv2.drawContours(piece, contours, -1, (0,255,0), 1)

plt.axis("off")
plt.title('Контур')
plt.imshow(piece);
